# %% [markdown]
# # NN. Chapter title
#
# **Owner:** name  \
# **Inputs:** which `PATHS` entries this chapter reads  \
# **Outputs:** figures written to `reports/figures/`, data to `data/processed/`
#
# ## Purpose
#
# One paragraph: which research question this chapter answers, and what a reader
# should be able to conclude by the end of it.

# %% [markdown]
# ## Setup

# %%
import warnings

import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from wildfires.config import CONVENTIONS, MIN_FIRE_HA, PATHS, STUDY_YEARS
from wildfires.viz import apply_theme, save_figure

apply_theme()
warnings.filterwarnings("ignore", category=FutureWarning)

pd.set_option("display.max_columns", 60)
pd.set_option("display.width", 140)

# %% [markdown]
# ## 1. Load

# %%
# Load via wildfires.io — never read a path directly.

# %% [markdown]
# ## 2. Analysis

# %%
# TODO

# %% [markdown]
# ## Takeaways
#
# -
# -
